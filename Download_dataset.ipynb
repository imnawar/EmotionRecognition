# %% [markdown]
# <a href="https://colab.research.google.com/github/imnawar/FaceDetection/blob/main/Download_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#My token


# Python program to write JSON
# to a file
import json

# Data to be written
dictionary = {"username":"imanawar","key":"8a39e9fa45fc2924d031f36a89e8879d"}

with open("kaggle.json", "w") as outfile:
	json.dump(dictionary, outfile)

# %%
# !pip install -q kaggle

# %%
# from google.colab import files
# files.upload()

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.12 / client 1.5.16)
# ref                                                   title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rahulvyasm/netflix-movies-and-tv-shows                Netflix Movies and TV Shows                       1MB  2024-04-10 09:48:38           2839         57  1.0
# sudarshan24byte/online-food-dataset                   Online Food Dataset                               3KB  2024-03-02 18:50:30          29598        570  0.9411765
# akankshaaa013/top-grossing-movies-dataset             Top Grossing Movies Dataset                      33KB  2024-04-08 08:29:47           1459         32  1.0
# sanyacodes/movies-dataset-netflix-prime-video-disney  Movies Dataset (Netflix, Prime Video, Disney+)  166KB  2024-04-12 05:10:53           1059         29  0.8235294
# asaniczka/university-employee-salaries-2011-present   University Employee Salaries (2011 - Present)    17MB  2024-04-07 10:11:15           1329         39  1.0
# mexwell/heart-disease-dataset                         🫀 Heart Disease Dataset                         399KB  2024-04-08 09:43:49           1578         31  1.0
# nitishjolly/consumers-buying-behavior                 Consumer's Buying Behavior                        1KB  2024-04-17 02:22:44            567         21  0.88235295
# fatemehmehrparvar/obesity-levels                      Obesity Levels                                   58KB  2024-04-07 16:28:30           2795         53  0.88235295
# arnavsmayan/amazon-prime-userbase-dataset             Amazon Prime Userbase Dataset                   104KB  2024-04-15 06:25:10            978         26  1.0
# sahirmaharajj/water-quality-data                      Water Quality Data                               32KB  2024-04-14 14:03:54            479         24  1.0
# sahirmaharajj/employee-salaries-analysis              Employee Salaries Analysis                      101KB  2024-03-31 16:32:47           2154         56  1.0
# bhavikjikadara/student-study-performance              Student Study Performance                         9KB  2024-03-07 06:14:09          13978        175  1.0
# prishasawhney/email-classification-ham-spam           Email Classification (Ham-Spam)                   4KB  2024-04-16 23:08:01            278         27  1.0
# sakshisatre/social-advertisement-dataset              Social Media Consumer Buying Behavior Dataset     1KB  2024-04-14 08:47:43            778         28  1.0
# sanyamgoyal401/customer-purchases-behaviour-dataset   Customer Purchases Behaviour Dataset              1MB  2024-04-06 18:42:01           2119         46  1.0
# startalks/pii-models                                  pii-models                                        1GB  2024-03-21 21:23:40            178         22  1.0
# sukhmandeepsinghbrar/most-subscribed-youtube-channel  Most Subscribed YouTube Channel                   1KB  2024-04-10 20:33:05           1471         42  1.0
# susanta21/student-attitude-and-behavior               Student Attitude and Behavior                     5KB  2024-04-13 12:16:32           1004         29  1.0
# nbroad/gemma-rewrite-nbroad                           gemma-rewrite-nbroad                              8MB  2024-03-03 04:52:39           1720        105  1.0
# middlehigh/lamborghini-sales-and-stocks               Lamborghini Sales and Stocks                      8KB  2024-04-15 03:15:52            639         21  1.0

# %%
# !kaggle datasets download -d 'mahmoudima/mma-facial-expression'
# Out:
# Downloading mma-facial-expression.zip to /content
#  92% 153M/166M [00:01<00:00, 112MB/s]
# 100% 166M/166M [00:01<00:00, 128MB/s]

# %%
from zipfile import ZipFile
from pathlib import Path
import os

# %%
def extract_data(zipfile_path: Path, destination_path: Path) -> None:
    '''Extracts zipfile'''

    if destination_path.is_dir():
        print(f"{destination_path} exists.")
    else:
        print(f"{destination_path} doesn't exist, creating one...")
        destination_path.mkdir(parents=True, exist_ok=True)

    if not os.listdir(destination_path):
        with ZipFile(zipfile_path, 'r') as zip:
            print("Extracting files...")
            zip.extractall(destination_path)

            print("Extracting finished.")
    else:
        print("Data already extracted.")

data_path = Path("/content")
zipfile_path = data_path / "/content/mma-facial-expression.zip"
images_path = data_path / "emotions_dataset"

extract_data(zipfile_path, images_path)
# Out:
# /content/emotions_dataset doesn't exist, creating one...
# Extracting files...
# Extracting finished.

# %%
len(os.listdir('/content/emotions_dataset/MMAFEDB/valid/angry'))
# Out:
# 1017

# %%
angry_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/angry')

# %%
type(angry_images_valid)
# Out:
# list

# %%
#create new df
angry_images_valid_df = pd.DataFrame({'img':angry_images_valid})
print(angry_images_valid_df)
# Out:
#                                img
# 0                  Angry.28759.jpg
# 1                  Angry.29671.jpg
# 2                  Angry.31442.jpg
# 3                  Angry.31491.jpg
# 4                  Angry.29851.jpg
# ...                            ...
# 1012       683Exp0angry_boy_78.jpg
# 1013               Angry.30305.jpg
# 1014               Angry.30815.jpg
# 1015   751Exp0angry_chinese_59.jpg
# 1016  146Exp0angry_African_112.jpg
#
# [1017 rows x 1 columns]

# %%
angry_images_valid_df.to_csv('angry_images_valid.csv')

# %%
angry_images_valid_df['class'] = 'angray'

# %%
angry_images_valid_df
# Out:
#                                img   class
# 0                  Angry.28759.jpg  angray
# 1                  Angry.29671.jpg  angray
# 2                  Angry.31442.jpg  angray
# 3                  Angry.31491.jpg  angray
# 4                  Angry.29851.jpg  angray
# ...                            ...     ...
# 1012       683Exp0angry_boy_78.jpg  angray
# 1013               Angry.30305.jpg  angray
# 1014               Angry.30815.jpg  angray
# 1015   751Exp0angry_chinese_59.jpg  angray
# 1016  146Exp0angry_African_112.jpg  angray
#
# [1017 rows x 2 columns]

# %%
angry_images_valid_df['type'] = 'valid'

# %%
import csv

# Specify the file name
filename = 'angry_images_valid.csv'

# field names
fields = ['img']
# Write the rows data to the CSV file with quotes around each field
with open(filename, 'w', newline='') as csvfile:
    # creating a csv dict writer object
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)

    # writing the fields
    csvwriter.writerow(fields)

    # writing the data rows
    csvwriter.writerows(angry_images_valid)

print(f"Names have been written to {filename}")
# Out:
# Names have been written to angry_images_valid.csv

# %%
import csv
with open('angry_images_valid.csv', 'w', newline='') as csvfile:
    writer_file = csv.writer(csvfile, delimiter=',')
    writer_file.writerow(angry_images_valid)

# %%
import pandas as pd

# %%
csv_file = pd.read_csv('angry_images_valid.csv')

# %%
csv_file
# Out:
# Empty DataFrame
# 653               Disgust.32289.jpg
# 654  6317Exp1fierce_chinese_793.jpg
# 655  6912Exp1fierce_husband_197.jpg
#
# [656 rows x 1 columns]

# %%
disgust_images_valid_df['class'] = 'disgust'

# %%
disgust_images_valid_df['type'] = 'valid'

# %%
disgust_images_valid_df
# Out:
#                                 img    class   type
# 0       14221Exp1mad_couple_129.jpg  disgust  valid
# 1    4781Exp1annoyed_infant_446.jpg  disgust  valid
# 2                 Disgust.30252.jpg  disgust  valid
# 3       5149Exp1awe_soldier_245.jpg  disgust  valid
# 4      6137Exp1fierce_asian_513.jpg  disgust  valid
# ..                              ...      ...    ...
# 651   3097Exp1angry_teacher_224.jpg  disgust  valid
# 652       2950Exp1angry_son_556.jpg  disgust  valid
# 653               Disgust.32289.jpg  disgust  valid
# 654  6317Exp1fierce_chinese_793.jpg  disgust  valid
# 655  6912Exp1fierce_husband_197.jpg  disgust  valid
#
# [656 rows x 3 columns]

# %%
fear_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/fear')

# %%
#create new df
fear_images_valid_df = pd.DataFrame({'img':fear_images_valid})

# %%
fear_images_valid_df['class'] = 'fear'

# %%
fear_images_valid_df['type'] = 'valid'

# %%
fear_images_valid_df
# Out:
#                                      img class   type
# 0                         Fear.30482.jpg  fear  valid
# 1                         Fear.30558.jpg  fear  valid
# 2          16527Exp2anxious_face_432.jpg  fear  valid
# 3       16217Exp2anxious_African_165.jpg  fear  valid
# 4                         Fear.28979.jpg  fear  valid
# ..                                   ...   ...    ...
# 654            2045Exp2angry_man_676.jpg  fear  valid
# 655  16482Exp2anxious_expression_370.jpg  fear  valid
# 656                       Fear.29777.jpg  fear  valid
# 657                       Fear.31495.jpg  fear  valid
# 658                       Fear.31920.jpg  fear  valid
#
# [659 rows x 3 columns]

# %%
happy_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/happy')

# %%
#create new df
happy_images_valid_df = pd.DataFrame({'img':happy_images_valid})

# %%
happy_images_valid_df['class'] = 'happy'

# %%
happy_images_valid_df['type'] = 'valid'

# %%
happy_images_valid_df
# Out:
#                                        img  class   type
# 0                          Happy.29856.jpg  happy  valid
# 1     16664Exp3anxious_grandfather_253.jpg  happy  valid
# 2         4177Exp3annoyed_european_389.jpg  happy  valid
# 3         17095Exp3anxious_student_674.jpg  happy  valid
# 4               14042Exp3mad_black_242.jpg  happy  valid
# ...                                    ...    ...    ...
# 5470          26496Exp3mad_manager_305.jpg  happy  valid
# 5471        8140Exp3fighting_actor_486.jpg  happy  valid
# 5472         11943Exp3hostile_face_513.jpg  happy  valid
# 5473  16680Exp3anxious_grandfather_653.jpg  happy  valid
# 5474         16533Exp3anxious_face_572.jpg  happy  valid
#
# [5475 rows x 3 columns]

# %%
neutral_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/neutral')

# %%
#create new df
neutral_images_valid_df = pd.DataFrame({'img':neutral_images_valid})

# %%
neutral_images_valid_df['class'] = 'neutral'

# %%
neutral_images_valid_df['type'] = 'valid'

# %%
neutral_images_valid_df
# Out:
#                                   img    class   type
# 0                   Neutral.30934.jpg  neutral  valid
# 1     9119Exp6fighting_family_741.jpg  neutral  valid
# 2        9651Exp6fighting_man_644.jpg  neutral  valid
# 3      6080Exp6fierce_African_717.jpg  neutral  valid
# 4      8100Exp6fighting_actor_212.jpg  neutral  valid
# ...                               ...      ...    ...
# 5834    2969Exp6angry_student_122.jpg  neutral  valid
# 5835    4355Exp6annoyed_family_35.jpg  neutral  valid
# 5836   7111Exp6fierce_manager_152.jpg  neutral  valid
# 5837    5226Exp6annoyed_people_58.jpg  neutral  valid
# 5838  3555Exp6annoyed_African_270.jpg  neutral  valid
#
# [5839 rows x 3 columns]

# %%
sad_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/sad')
sad_images_valid_df = pd.DataFrame({'img':sad_images_valid})
sad_images_valid_df['class'] = 'sad'
sad_images_valid_df['type'] = 'valid'
sad_images_valid_df
# Out:
#                                       img class   type
# 0           10561Exp4fighting_son_885.jpg   sad  valid
# 1     4554Exp4annoyed_grandfather_247.jpg   sad  valid
# 2                           Sad.31616.jpg   sad  valid
# 3           7941Exp4fierce_worker_137.jpg   sad  valid
# 4             15284Exp4mad_people_466.jpg   sad  valid
# ...                                   ...   ...    ...
# 2231                        Sad.30298.jpg   sad  valid
# 2232        883Exp4angry_european_154.jpg   sad  valid
# 2233                        Sad.30383.jpg   sad  valid
# 2234                        Sad.31424.jpg   sad  valid
# 2235        227Exp4angry_american_258.jpg   sad  valid
#
# [2236 rows x 3 columns]

# %%
surprise_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/surprise')
surprise_images_valid_df = pd.DataFrame({'img':surprise_images_valid})
surprise_images_valid_df['class'] = 'surprise'
surprise_images_valid_df['type'] = 'valid'
surprise_images_valid_df
# Out:
#                                     img     class   type
# 0                    Surprise.28838.jpg  surprise  valid
# 1          3308Exp5angry_worker_131.jpg  surprise  valid
# 2        13461Exp5hostile_woman_120.jpg  surprise  valid
# 3      12673Exp5hostile_manager_739.jpg  surprise  valid
# 4           6565Exp5fierce_face_332.jpg  surprise  valid
# ...                                 ...       ...    ...
# 1469   13325Exp5hostile_teacher_603.jpg  surprise  valid
# 1470  10361Exp5fighting_soldier_131.jpg  surprise  valid
# 1471   7472Exp5fierce_president_604.jpg  surprise  valid
# 1472     10791Exp5fighting_wife_550.jpg  surprise  valid
# 1473    8710Exp5fighting_couple_457.jpg  surprise  valid
#
# [1474 rows x 3 columns]

# %%
valid_df = pd.concat([angry_images_valid_df, disgust_images_valid_df,
                      fear_images_valid_df, happy_images_valid_df,
                      neutral_images_valid_df, sad_images_valid_df,
                      surprise_images_valid_df], ignore_index=True)

# %%
valid_df.head()
# Out:
#                img   class   type
# 0  Angry.28759.jpg  angray  valid
# 1  Angry.29671.jpg  angray  valid
# 2  Angry.31442.jpg  angray  valid
# 3  Angry.31491.jpg  angray  valid
# 4  Angry.29851.jpg  angray  valid

# %%
valid_df.tail()
# Out:
#                                      img     class   type
# 17351   13325Exp5hostile_teacher_603.jpg  surprise  valid
# 17352  10361Exp5fighting_soldier_131.jpg  surprise  valid
# 17353   7472Exp5fierce_president_604.jpg  surprise  valid
# 17354     10791Exp5fighting_wife_550.jpg  surprise  valid
# 17355    8710Exp5fighting_couple_457.jpg  surprise  valid
