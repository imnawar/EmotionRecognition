# %% [markdown]
# <a href="https://colab.research.google.com/github/imnawar/FaceDetection/blob/main/Download_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#My token


# Python program to write JSON
# to a file
import json

# Data to be written
dictionary = {"username":"imanawar","key":"8a39e9fa45fc2924d031f36a89e8879d"}

with open("kaggle.json", "w") as outfile:
	json.dump(dictionary, outfile)

# %%
# !pip install -q kaggle

# %%
# from google.colab import files
# files.upload()

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                  title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rahulvyasm/netflix-movies-and-tv-shows               Netflix Movies and TV Shows                      1MB  2024-04-10 09:48:38           5281        111  1.0
# sahirmaharajj/youth-tobacco-survey                   Youth Tobacco Dataset (2 Decades)              264KB  2024-04-11 20:19:31           1129         23  1.0
# alistairking/u-s-co2-emissions                       CO2 Emissions (in U.S.)                        546KB  2024-04-20 21:22:34            559         25  1.0
# mexwell/heart-disease-dataset                        🫀 Heart Disease Dataset                        399KB  2024-04-08 09:43:49           2805         51  1.0
# ...

# %%
# !kaggle datasets download -d 'mahmoudima/mma-facial-expression'
# Out:
# ...
#  99% 164M/166M [00:01<00:00, 153MB/s]
# 100% 166M/166M [00:01<00:00, 131MB/s]

# %%
from zipfile import ZipFile
from pathlib import Path
import os

# %%
def extract_data(zipfile_path: Path, destination_path: Path) -> None:
    '''Extracts zipfile'''

    if destination_path.is_dir():
        print(f"{destination_path} exists.")
    else:
        print(f"{destination_path} doesn't exist, creating one...")
        destination_path.mkdir(parents=True, exist_ok=True)

    if not os.listdir(destination_path):
        with ZipFile(zipfile_path, 'r') as zip:
            print("Extracting files...")
            zip.extractall(destination_path)

            print("Extracting finished.")
    else:
        print("Data already extracted.")

data_path = Path("/content")
zipfile_path = data_path / "/content/mma-facial-expression.zip"
images_path = data_path / "emotions_dataset"

extract_data(zipfile_path, images_path)
# Out:
# /content/emotions_dataset doesn't exist, creating one...
# Extracting files...
# Extracting finished.

# %%
len(os.listdir('/content/emotions_dataset/MMAFEDB/valid/angry'))
# Out:
# 1017

# %%
angry_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/angry')

# %%
type(angry_images_valid)
# Out:
# list

# %%
import pandas as pd

# %%
#create new df
angry_images_valid_df = pd.DataFrame({'img':angry_images_valid})
print(angry_images_valid_df)
# Out:
#                                    img
# 0         977Exp0angry_european_80.jpg
# 1                      Angry.29671.jpg
# 2             607Exp0angry_boy_243.jpg
# 3     1015Exp0angry_expression_166.jpg
# 4        267Exp0angry_american_629.jpg
# ...                                ...
# 1012       818Exp0angry_couple_293.jpg
# 1013         1187Exp0angry_face_76.jpg
# 1014       811Exp0angry_couple_263.jpg
# 1015                   Angry.31310.jpg
# 1016                   Angry.30484.jpg
#
# [1017 rows x 1 columns]

# %%
angry_images_valid_df.to_csv('angry_images_valid.csv')

# %%
angry_images_valid_df['class'] = 'angry'

# %%
angry_images_valid_df
# Out:
#                                    img  class   type
# 0         977Exp0angry_european_80.jpg  angry  valid
# 1                      Angry.29671.jpg  angry  valid
# 2             607Exp0angry_boy_243.jpg  angry  valid
# 3     1015Exp0angry_expression_166.jpg  angry  valid
# 4        267Exp0angry_american_629.jpg  angry  valid
# ...                                ...    ...    ...
# 1012       818Exp0angry_couple_293.jpg  angry  valid
# 1013         1187Exp0angry_face_76.jpg  angry  valid
# 1014       811Exp0angry_couple_263.jpg  angry  valid
# 1015                   Angry.31310.jpg  angry  valid
# 1016                   Angry.30484.jpg  angry  valid
#
# [1017 rows x 3 columns]

# %%
angry_images_valid_df['type'] = 'valid'

# %%
import csv

# Specify the file name
filename = 'angry_images_valid.csv'

# field names
fields = ['img']
# Write the rows data to the CSV file with quotes around each field
with open(filename, 'w', newline='') as csvfile:
    # creating a csv dict writer object
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)

    # writing the fields
    csvwriter.writerow(fields)

    # writing the data rows
    csvwriter.writerows(angry_images_valid)

print(f"Names have been written to {filename}")
# Out:
# Names have been written to angry_images_valid.csv

# %%
import csv
with open('angry_images_valid.csv', 'w', newline='') as csvfile:
    writer_file = csv.writer(csvfile, delimiter=',')
    writer_file.writerow(angry_images_valid)

# %%
import pandas as pd

# %%
csv_file = pd.read_csv('angry_images_valid.csv')

# %%
csv_file
# Out:
# Empty DataFrame
# ...

# %%
disgust_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/disgust')

# %%
#create new df
disgust_images_valid_df = pd.DataFrame({'img':disgust_images_valid})
print(disgust_images_valid_df)
# Out:
#                                    img
# 0         14190Exp1mad_chinese_181.jpg
# 1    6506Exp1fierce_expression_331.jpg
# 2        3081Exp1angry_teacher_132.jpg
# 3      6440Exp1fierce_european_399.jpg
# 4      2692Exp1angry_president_630.jpg
# ..                                 ...
# 651      3026Exp1angry_student_418.jpg
# 652     5814Exp1annoyed_worker_187.jpg
# 653       9948Exp1fighting_old_349.jpg
# 654        4929Exp1awe_soldier_496.jpg
# 655       4531Exp1annoyed_girl_616.jpg
#
# [656 rows x 1 columns]

# %%
disgust_images_valid_df['class'] = 'disgust'

# %%
disgust_images_valid_df['type'] = 'valid'

# %%
disgust_images_valid_df
# Out:
#                                    img    class   type
# 0         14190Exp1mad_chinese_181.jpg  disgust  valid
# 1    6506Exp1fierce_expression_331.jpg  disgust  valid
# 2        3081Exp1angry_teacher_132.jpg  disgust  valid
# 3      6440Exp1fierce_european_399.jpg  disgust  valid
# 4      2692Exp1angry_president_630.jpg  disgust  valid
# ..                                 ...      ...    ...
# 651      3026Exp1angry_student_418.jpg  disgust  valid
# 652     5814Exp1annoyed_worker_187.jpg  disgust  valid
# 653       9948Exp1fighting_old_349.jpg  disgust  valid
# 654        4929Exp1awe_soldier_496.jpg  disgust  valid
# 655       4531Exp1annoyed_girl_616.jpg  disgust  valid
#
# [656 rows x 3 columns]

# %%
fear_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/fear')

# %%
#create new df
fear_images_valid_df = pd.DataFrame({'img':fear_images_valid})

# %%
fear_images_valid_df['class'] = 'fear'

# %%
fear_images_valid_df['type'] = 'valid'

# %%
fear_images_valid_df
# Out:
#                                  img class   type
# 0                     Fear.30250.jpg  fear  valid
# 1                     Fear.30279.jpg  fear  valid
# 2    14722Exp2mad_grandmother_72.jpg  fear  valid
# 3           15211Exp2mad_old_222.jpg  fear  valid
# 4      11448Exp2hostile_boss_206.jpg  fear  valid
# ..                               ...   ...    ...
# 654                   Fear.31864.jpg  fear  valid
# 655                   Fear.30723.jpg  fear  valid
# 656                   Fear.31441.jpg  fear  valid
# 657                   Fear.31560.jpg  fear  valid
# 658                   Fear.30335.jpg  fear  valid
#
# [659 rows x 3 columns]

# %%
happy_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/happy')

# %%
#create new df
happy_images_valid_df = pd.DataFrame({'img':happy_images_valid})

# %%
happy_images_valid_df['class'] = 'happy'

# %%
happy_images_valid_df['type'] = 'valid'

# %%
happy_images_valid_df
# Out:
#                                     img  class   type
# 0        16067Exp3fierce_father_737.jpg  happy  valid
# 1         10539Exp3fighting_son_597.jpg  happy  valid
# 2           14545Exp3mad_family_605.jpg  happy  valid
# 3     20520Exp3angry_programmer_649.jpg  happy  valid
# 4       24506Exp3fighting_woman_182.jpg  happy  valid
# ...                                 ...    ...    ...
# 5470       6149Exp3fierce_asian_699.jpg  happy  valid
# 5471   21516Exp3annoyed_husband_749.jpg  happy  valid
# 5472         15877Exp3mad_woman_472.jpg  happy  valid
# 5473       22725Exp3fierce_lady_750.jpg  happy  valid
# 5474      2197Exp3angry_manager_672.jpg  happy  valid
#
# [5475 rows x 3 columns]

# %%
neutral_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/neutral')

# %%
#create new df
neutral_images_valid_df = pd.DataFrame({'img':neutral_images_valid})

# %%
neutral_images_valid_df['class'] = 'neutral'

# %%
neutral_images_valid_df['type'] = 'valid'

# %%
neutral_images_valid_df
# Out:
#                                    img    class   type
# 0     9439Exp6fighting_husband_185.jpg  neutral  valid
# 1      8712Exp6fighting_couple_491.jpg  neutral  valid
# 2        6360Exp6fierce_couple_336.jpg  neutral  valid
# 3       7104Exp6fierce_manager_120.jpg  neutral  valid
# 4        939Exp6angry_european_452.jpg  neutral  valid
# ...                                ...      ...    ...
# 5834  7350Exp6fierce_president_144.jpg  neutral  valid
# 5835     3746Exp6annoyed_black_126.jpg  neutral  valid
# 5836         358Exp6angry_asian_76.jpg  neutral  valid
# 5837    3605Exp6annoyed_African_81.jpg  neutral  valid
# 5838   9115Exp6fighting_family_682.jpg  neutral  valid
#
# [5839 rows x 3 columns]

# %%
sad_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/sad')
sad_images_valid_df = pd.DataFrame({'img':sad_images_valid})
sad_images_valid_df['class'] = 'sad'
sad_images_valid_df['type'] = 'valid'
sad_images_valid_df
# Out:
#                                     img class   type
# 0         7974Exp4fierce_worker_373.jpg   sad  valid
# 1          2524Exp4angry_people_745.jpg   sad  valid
# 2       8247Exp4fighting_African_61.jpg   sad  valid
# 3      11203Exp4hostile_African_252.jpg   sad  valid
# 4        4338Exp4annoyed_family_176.jpg   sad  valid
# ...                                 ...   ...    ...
# 2231       9568Exp4fighting_lady_49.jpg   sad  valid
# 2232   10565Exp4fighting_student_10.jpg   sad  valid
# 2233                      Sad.29936.jpg   sad  valid
# 2234     11342Exp4hostile_asian_218.jpg   sad  valid
# 2235  11287Exp4hostile_american_282.jpg   sad  valid
#
# [2236 rows x 3 columns]

# %%
surprise_images_valid = os.listdir('/content/emotions_dataset/MMAFEDB/valid/surprise')
surprise_images_valid_df = pd.DataFrame({'img':surprise_images_valid})
surprise_images_valid_df['class'] = 'surprise'
surprise_images_valid_df['type'] = 'valid'
surprise_images_valid_df
# Out:
#                                      img     class   type
# 0       13178Exp5hostile_student_121.jpg  surprise  valid
# 1     12968Exp5hostile_president_541.jpg  surprise  valid
# 2                     Surprise.30048.jpg  surprise  valid
# 3                     Surprise.29791.jpg  surprise  valid
# 4                     Surprise.30412.jpg  surprise  valid
# ...                                  ...       ...    ...
# 1469                  Surprise.30136.jpg  surprise  valid
# 1470     11022Exp5fighting_worker_80.jpg  surprise  valid
# 1471      6935Exp5fierce_husband_547.jpg  surprise  valid
# 1472           2312Exp5angry_old_150.jpg  surprise  valid
# 1473      7113Exp5fierce_manager_161.jpg  surprise  valid
#
# [1474 rows x 3 columns]

# %%
valid_df = pd.concat([angry_images_valid_df, disgust_images_valid_df,
                      fear_images_valid_df, happy_images_valid_df,
                      neutral_images_valid_df, sad_images_valid_df,
                      surprise_images_valid_df], ignore_index=True)

# %%
valid_df.head()
# Out:
#                                 img  class   type
# 0      977Exp0angry_european_80.jpg  angry  valid
# 1                   Angry.29671.jpg  angry  valid
# 2          607Exp0angry_boy_243.jpg  angry  valid
# 3  1015Exp0angry_expression_166.jpg  angry  valid
# 4     267Exp0angry_american_629.jpg  angry  valid

# %%
valid_df.tail()
# Out:
#                                    img     class   type
# 17351               Surprise.30136.jpg  surprise  valid
# 17352  11022Exp5fighting_worker_80.jpg  surprise  valid
# 17353   6935Exp5fierce_husband_547.jpg  surprise  valid
# 17354        2312Exp5angry_old_150.jpg  surprise  valid
# 17355   7113Exp5fierce_manager_161.jpg  surprise  valid

# %%
data = valid_df

# %%
for label in list(valid_df['class'].unique()):
  img_paths = os.listdir('/content/emotions_dataset/MMAFEDB/train/'+label)
  df = pd.DataFrame({'img':img_paths})
  df['class'] = label
  df['type'] = 'train'
  data = pd.concat([data, df], ignore_index=True)

# %%
data
# Out:
#                                            img     class   type
# 0                 977Exp0angry_european_80.jpg     angry  valid
# 1                              Angry.29671.jpg     angry  valid
# 2                     607Exp0angry_boy_243.jpg     angry  valid
# 3             1015Exp0angry_expression_166.jpg     angry  valid
# 4                267Exp0angry_american_629.jpg     angry  valid
# ...                                        ...       ...    ...
# 110319                      Surprise.26557.jpg  surprise  train
# 110320                      Surprise.24092.jpg  surprise  train
# 110321                      Surprise.19351.jpg  surprise  train
# 110322  55526Exp5horrified_grandmother_132.jpg  surprise  train
# 110323       45696Exp5heartbroken_wife_799.jpg  surprise  train
#
# [110324 rows x 3 columns]

# %%
for label in list(valid_df['class'].unique()):
  img_paths = os.listdir('/content/emotions_dataset/MMAFEDB/test/'+label)
  df = pd.DataFrame({'img':img_paths})
  df['class'] = label
  df['type'] = 'test'
  data = pd.concat([data, df], ignore_index=True)

# %%
data
# Out:
#                                                    img     class   type
# 0                         977Exp0angry_european_80.jpg     angry  valid
# 1                                      Angry.29671.jpg     angry  valid
# 2                             607Exp0angry_boy_243.jpg     angry  valid
# 3                     1015Exp0angry_expression_166.jpg     angry  valid
# 4                        267Exp0angry_american_629.jpg     angry  valid
# ...                                                ...       ...    ...
# 127675                    16348Exp5anxious_boy_654.jpg  surprise   test
# 127676  17513Exp5frightened_by_the_movie_asian_586.jpg  surprise   test
# 127677          18644Exp5frightened_expression_172.jpg  surprise   test
# 127678          19188Exp5frightened_programmer_298.jpg  surprise   test
# 127679                              Surprise.32334.jpg  surprise   test
#
# [127680 rows x 3 columns]

# %%
len(os.listdir('/content/emotions_dataset/MMAFEDB/train/'))
# Out:
# 7

# %%
f = []
for (dirpath, dirnames, filenames) in os.walk('/content/emotions_dataset/MMAFEDB/'):
    f.extend(filenames)

# %%
len(f)
# Out:
# 127680

# %%
data.to_csv('emotion_dataset.csv')
